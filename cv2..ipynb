# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img_rgb = cv2.imread('res_mario.jpg')
print img_rgb.shape
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
template = cv2.imread('coin.jpg',0)
print template.shape
w, h = template.shape[::-1]

res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)
print res
threshold = 0.8
loc = np.where( res >= threshold)
print loc
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,0,255), 1)

#cv2.imwrite('res.jpg',img_rgb)
#pl='./res.jpg'
#im=cv2.imread(img_rgb)
gr = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB)

plt.imshow(gr)
plt.show()
# Out:
# (231, 244, 3)
# (33, 17)
# [[-0.18670917 -0.17151015 -0.16114831 ... -0.18743911 -0.16918553
#   -0.15873098]
#  [-0.12958007 -0.10459215 -0.09782295 ... -0.13165839 -0.105822
#   -0.09868615]
#  [-0.07319844 -0.04388398 -0.03864947 ... -0.07711001 -0.04364893
#   -0.0392171 ]
#  ...
#  [-0.03365428 -0.00351894  0.03235302 ... -0.02799272 -0.00261134
#    0.02864167]
#  [-0.06192254 -0.02212757 -0.00177857 ... -0.06061321 -0.01892653
#   -0.003559  ]
#  [-0.05410149  0.0144213   0.04367039 ... -0.04986315  0.01209746
#    0.04286354]]
# (array([ 62,  62,  62,  62,  62,  62,  62,  62,  62,  63,  63,  63,  63,
#         63,  63,  63,  63,  63,  63,  63,  63,  63,  64,  64,  64,  64,
#         64,  64,  64,  64,  94,  94,  94,  94,  94,  94,  94,  94,  94,
#         94,  94,  94,  94,  95,  95,  95,  95,  95,  95,  95,  95,  95,
#         95,  95,  95,  95,  95,  95,  95,  95,  95,  96,  96,  96,  96,
#         96,  96,  96,  96,  96,  96,  96,  96, 127, 127, 127, 127, 127,
#        127, 127]), array([ 68,  82,  83,  96,  97, 110, 111, 124, 125,  67,  68,  69,  81,
#         82,  83,  95,  96,  97, 110, 111, 124, 125,  68,  82,  96,  97,
#        110, 111, 124, 125,  53,  54,  68,  82,  83,  96,  97, 110, 111,
#        124, 125, 138, 139,  53,  54,  55,  67,  68,  69,  81,  82,  83,
#         95,  96,  97, 110, 111, 124, 125, 138, 139,  53,  54,  68,  82,
#         96,  97, 110, 111, 124, 125, 138, 139,  54,  68,  82,  96, 110,
#        124, 138]))
